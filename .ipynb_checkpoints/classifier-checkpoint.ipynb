# %%
from src.ingredient_classifier import enrich_database

df = enrich_database(
    "paulaschoice_us_ingredients_clean.csv",
    "paulaschoice_us_ingredients_enriched.csv"
)

df.head()
