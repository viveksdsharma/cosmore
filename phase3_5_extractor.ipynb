# %%
from src.ingredient_extractor import extract_ingredient_candidates

sample = """
NOREDIENTS Agua, Cyclopentasiloxane,
De methic one, Isohexadecane
"""

candidates = extract_ingredient_candidates(sample)

print(candidates)
# Out:
# ['agua', 'cyclopentasiloxane', 'de methic one', 'isohexadecane']
