# %%
from src.extract_and_match import extract_and_match_from_text

sample_ocr = """
NOREDIENTS Agua, Cyclopentasiloxane, Glycerine, Caprylic/-
| pride, De methic one, Isohexadecane, Cetyl Alcohol,
rate (and! PEG 109 Stearate, Butyrospermum
3) Butter, \Wwiitvlgt hicowde (and] Anhydroxylitol (and)
ing ide, Ciye erin (and) Aqua [and] Butylene Glycol
nel ‘land’ Poiysarbate 20 tand] Palmitoyl
Bari) Parnioyt fetrapeptide-7, Fragaria Ananassa
tier it Ext) act, Sodium Hyaluronate, Rubus Cnamae-
gerry] Gord Oil, Panthenol, Cetearyl Aicons. Pasy-
—_ a lysorbate 80, Ammon TALIS.
"""

df = extract_and_match_from_text(sample_ocr, threshold=80)
display(df[["Input", "Matched Name", "Score"]])
print("Recovered:", df["Matched Name"].notna().sum())
# Out:
#                                                 Input  \
# 0                                     noredients agua
# 1                                  cyclopentasiloxane
# 2                                           glycerine
# 3                                      caprylic pride
# 4                                       de methic one
# 5                                       isohexadecane
# 6                                       cetyl alcohol
# 7                               rate peg 109 stearate
# 8                              butyrospermum 3 butter
# 9            wwiitvlgt hicowde anhydroxylitol ing ide
# 10  ciye erin aqua butylene glycol nel land polyso...
# 11                                     polysorbate 20
# 12                                    butylene glycol
# 13                                     ciye erin aqua
# 14                               nel land polysorbate
# 15        tand palmitoyl bari parnioyt tetrapeptide-7
# 16                  fragaria ananassa tier it extract
# 17                          fragaria ananassa extract
# 18                                 sodium hyaluronate
# 19                         rubus cnamaegerry seed oil
# 20                                     rubus seed oil
# 21                                          panthenol
# 22                cetearyl aicons pasy polysorbate 80
# 23                                     polysorbate 80
# 24                                        ammon talis
#
#                          Matched Name       Score
# 0                                 UVA   80.000000
# 1                  Cyclopentasiloxane  100.000000
# 2                           Glycerine  100.000000
# 3                        Triglyceride  100.000000
# 4                           Methicone   88.888889
# 5                       Isohexadecane  100.000000
# 6                       Cetyl Alcohol  100.000000
# 7                                 TEA  100.000000
# 8                              Butter  100.000000
# 9                      Anhydroxylitol  100.000000
# 10                     Tetrapeptide-7  100.000000
# 11                     Polysorbate 20  100.000000
# 12                    Butylene Glycol  100.000000
# 13                                UVA   80.000000
# 14                     Polysorbate 20  100.000000
# 15                     Tetrapeptide-7  100.000000
# 16   Fragaria Ananassa Callus Extract  100.000000
# 17   Fragaria Ananassa Callus Extract  100.000000
# 18                 Sodium Hyaluronate  100.000000
# 19  Rubus Idaeus (Raspberry) Seed Oil  100.000000
# 20  Rubus Idaeus (Raspberry) Seed Oil  100.000000
# 21                          Panthenol  100.000000
# 22                     Polysorbate 80  100.000000
# 23                     Polysorbate 80  100.000000
# 24                            Ammonia   83.333333
# Recovered: 25

# %%
import os

os.listdir("src")
# Out:
# ['ocr_processor_v2.py',
#  'image_utils.py',
#  'extract_and_match.py',
#  '.DS_Store',
#  'ingredient_classifier.py',
#  '__init__.py',
#  '__pycache__',
#  'ocr_processor.py',
#  'ingredient_db.py',
#  'fuzzy_matcher.py',
#  'ingredient_extractor.py',
#  '.ipynb_checkpoints',
#  'ingredient_classifier.ipynb']

# %%
import os

print(os.getcwd())
# Out:
# /Users/viveksharma/Desktop/programming/scanner
